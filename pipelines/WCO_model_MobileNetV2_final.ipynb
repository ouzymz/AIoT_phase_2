# %% [markdown]
# # WCO Model MobileNetV2 -> alpha = 0.35 -> 160x160
# **Output:** contamination + colour
# **Inference:** FastAPI server (Keras float32)
# **ESP32:** sadece görüntü toplar, inference yok

# %%
# ── 1. Drive mount ────────────────────────────────────────────────
import os
from google.colab import drive

drive.mount('/content/drive')

DRIVE_DIR = '/content/drive/MyDrive/cropped160'
SAVE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.keras'

os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ── 2. Import ─────────────────────────────────────────────────────
import os, re
import numpy as np
import tensorflow as tf
import keras
from keras import layers, Model
from keras.applications import MobileNetV2
from sklearn.model_selection import train_test_split

IMG_SIZE   = 160
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE

print('TF version:', tf.__version__)

keras.utils.set_random_seed(42)
N_FOLDS = 3
# Out:
# TF version: 2.20.0

# %%
# ── 3. Label parse ────────────────────────────────────────────────
# Dosya adı formatı: t{0|1}_p{0|1}_c{0|1}_*.jpg
# turbidity, particle, colour ayrı ayrı öğrenilecek (3 bağımsız head)
def parse_label(filename):
    m = re.match(r't(\d)[_-]p(\d)[_-]c(\d)', filename)
    if not m:
        return None
    t, p, c = int(m.group(1)), int(m.group(2)), int(m.group(3))
    return np.array([t, p, c], dtype=np.float32)

all_files, all_labels = [], []

for fname in sorted(os.listdir(DRIVE_DIR)):
    if not (fname.endswith('.jpg') or fname.endswith('.jpeg')):
        continue

    lbl = parse_label(fname)
    if lbl is None:
        print(f'SKIP: {fname}')
        continue
    all_files.append(os.path.join(DRIVE_DIR, fname))
    all_labels.append(lbl)

all_labels = np.array(all_labels, dtype=np.float32)
print(f'Toplam        : {len(all_files)} görüntü')
print(f'turbidity   : {all_labels[:,0].sum():.0f} pozitif')
print(f'particle    : {all_labels[:,1].sum():.0f} pozitif')
print(f'colour      : {all_labels[:,2].sum():.0f} pozitif')
# Out:
# Toplam        : 296 görüntü
# turbidity   : 143 pozitif
# particle    : 143 pozitif
# colour      : 145 pozitif

# %%
# ── 4. K-fold split (K=3) ─────────────────────────────────────────
from sklearn.model_selection import StratifiedKFold

# 3 binary label → 8 bucket için birleşik etiket (multi-label stratification)
combined = (all_labels[:, 0].astype(int) * 4 +
            all_labels[:, 1].astype(int) * 2 +
            all_labels[:, 2].astype(int))

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
folds = list(skf.split(all_files, combined))

print(f'{N_FOLDS}-fold hazır')
for i, (tr, va) in enumerate(folds):
    print(f'  Fold {i+1}: train={len(tr)}  val={len(va)}')
# Out:
# 3-fold hazır
#   Fold 1: train=197  val=99
#   Fold 2: train=197  val=99
#   Fold 3: train=198  val=98

# %%
# # ── 4. Train / val / test split ───────────────────────────────────
# # Stratify: colour (en az varyans)
# colour_buckets = all_labels[:, 2].astype(int)

# files_train, files_temp, y_train, y_temp = train_test_split(
#     all_files, all_labels,
#     test_size=0.30, stratify=colour_buckets, random_state=42
# )
# colour_buckets_temp = y_temp[:, 2].astype(int)
# files_val, files_test, y_val, y_test = train_test_split(
#     files_temp, y_temp,
#     test_size=0.50, stratify=colour_buckets_temp, random_state=42
# )

# print(f'Train : {len(files_train)}')
# print(f'Val   : {len(files_val)}')
# print(f'Test  : {len(files_test)}')
# Out:
# Train : 207
# Val   : 44
# Test  : 45

# %%
# ── 5. tf.data pipeline ───────────────────────────────────────────
augment = keras.Sequential([
    layers.RandomFlip('horizontal_and_vertical'),
    layers.RandomRotation(0.08),
], name='augmentation')

def load_train(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0  # [0,1] — uint8 input ile uyumlu
    img = augment(img, training=True) #uyumsuz olursa kaldirilacak
    return img, {
        'turbidity': label[0:1],
        'particle':  label[1:2],
        'colour':    label[2:3],
    }

def load_eval(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0  # [0,1] — uint8 input ile uyumlu
    return img, {
        'turbidity': label[0:1],
        'particle':  label[1:2],
        'colour':    label[2:3],
    }

# train_ds = (tf.data.Dataset.from_tensor_slices((files_train, y_train))
#             .shuffle(len(files_train), seed=42)
#             .map(load_train, num_parallel_calls=AUTOTUNE)
#             .batch(BATCH_SIZE).prefetch(AUTOTUNE))

# val_ds = (tf.data.Dataset.from_tensor_slices((files_val, y_val))
#           .map(load_eval, num_parallel_calls=AUTOTUNE)
#           .batch(BATCH_SIZE).prefetch(AUTOTUNE))

# test_ds = (tf.data.Dataset.from_tensor_slices((files_test, y_test))
#            .map(load_eval, num_parallel_calls=AUTOTUNE)
#            .batch(BATCH_SIZE).prefetch(AUTOTUNE))

print('Pipeline hazır')
# Out:
# Pipeline hazır

# %%
# ── 6. Model ──────────────────────────────────────────────────────
def build_model():
    backbone = MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        alpha=0.35,
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    # x = layers.RandomFlip('horizontal')(inputs)
    # x = layers.RandomRotation(0.08)(x)
    # x = backbone(x, training=False)
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    out_turb = layers.Dense(1, activation='sigmoid', name='turbidity')(x)
    out_part = layers.Dense(1, activation='sigmoid', name='particle')(x)
    out_col  = layers.Dense(1, activation='sigmoid', name='colour')(x)

    model = Model(inputs=inputs, outputs={
        'turbidity': out_turb,
        'particle':  out_part,
        'colour':    out_col,
    })
    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            'turbidity': 'binary_crossentropy',
            'particle':  'binary_crossentropy',
            'colour':    'binary_crossentropy',
        },
        loss_weights={
            'turbidity': 1.0,
            'particle':  1.0,
            'colour':    1.0,
        },
        metrics={
            'turbidity': ['accuracy'],
            'particle':  ['accuracy'],
            'colour':    ['accuracy'],
        }
    )
    return model

model = build_model()
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_0.35_1… │ (None, 5, 5,      │    410,208 │ input_layer_5[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_0.35… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ colour (Dense)      │ (None, 1)         │        129 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ particle (Dense)    │ (None, 1)         │        129 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ turbidity (Dense)   │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 574,563 (2.19 MB)
#  Trainable params: 164,355 (642.01 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %%
# # ── 7. Eğitim ─────────────────────────────────────────────────────
# callbacks = [
#     keras.callbacks.EarlyStopping(
#         monitor='val_loss', patience=7, restore_best_weights=True
#     ),
#     keras.callbacks.ModelCheckpoint(
#         SAVE_PATH, monitor='val_loss', save_best_only=True
#     ),
#     keras.callbacks.ReduceLROnPlateau(
#         monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6
#     ),
# ]

# history = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=50,
#     callbacks=callbacks,
#     verbose=1
# )

# print(f'\nEn iyi model kaydedildi: {SAVE_PATH}')
# ── 7. K-fold CV eğitimi ──────────────────────────────────────────
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from collections import defaultdict

fold_results = []                   # her fold için per-label metrikler
fold_scores  = defaultdict(list)    # threshold seçimi için tüm fold skorları

for fold_idx, (train_idx, val_idx) in enumerate(folds):
    print(f'\n═══ Fold {fold_idx+1}/{N_FOLDS} ═══')

    files_tr = [all_files[i] for i in train_idx]
    files_va = [all_files[i] for i in val_idx]
    y_tr     = all_labels[train_idx]
    y_va     = all_labels[val_idx]

    train_ds = (tf.data.Dataset.from_tensor_slices((files_tr, y_tr))
                .shuffle(len(files_tr), seed=42)
                .map(load_train, num_parallel_calls=AUTOTUNE)
                .batch(BATCH_SIZE).prefetch(AUTOTUNE))
    val_ds = (tf.data.Dataset.from_tensor_slices((files_va, y_va))
              .map(load_eval, num_parallel_calls=AUTOTUNE)
              .batch(BATCH_SIZE).prefetch(AUTOTUNE))

    keras.backend.clear_session()
    keras.utils.set_random_seed(42 + fold_idx)
    model = build_model()

    cbs = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6),
    ]
    model.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=cbs, verbose=0)

    y_true_f = {'turbidity': [], 'particle': [], 'colour': []}
    sc_f     = {'turbidity': [], 'particle': [], 'colour': []}
    for imgs, labels in val_ds:
        preds = model.predict(imgs, verbose=0)
        for k in ['turbidity', 'particle', 'colour']:
            y_true_f[k].extend(labels[k].numpy().flatten())
            sc_f[k].extend(preds[k].flatten())

    metrics = {}
    for k in ['turbidity', 'particle', 'colour']:
        yp = [1 if s > 0.5 else 0 for s in sc_f[k]]
        metrics[k] = {
            'acc':    accuracy_score(y_true_f[k], yp),
            'prec':   precision_score(y_true_f[k], yp, zero_division=0),
            'recall': recall_score(y_true_f[k], yp, zero_division=0),
            'f1':     f1_score(y_true_f[k], yp, zero_division=0),
        }
        fold_scores[k].extend(list(zip(y_true_f[k], sc_f[k])))

    fold_results.append(metrics)
    for k in ['turbidity', 'particle', 'colour']:
        m = metrics[k]
        print(f'  {k:>10s}: acc={m["acc"]:.3f}  prec={m["prec"]:.3f}  '
              f'recall={m["recall"]:.3f}  f1={m["f1"]:.3f}')

# ── Final model: tüm veri üzerinde — TFLite export için ───────────
print(f'\n═══ Final model (tüm veri) ═══')
full_ds = (tf.data.Dataset.from_tensor_slices((all_files, all_labels))
           .shuffle(len(all_files), seed=42)
           .map(load_train, num_parallel_calls=AUTOTUNE)
           .batch(BATCH_SIZE).prefetch(AUTOTUNE))

keras.backend.clear_session()
keras.utils.set_random_seed(42)
final_model = build_model()
final_model.fit(full_ds, epochs=30, verbose=1)
final_model.save(SAVE_PATH)
print(f'Final model kaydedildi: {SAVE_PATH}')
# Out:
# ═══ Fold 1/3 ═══
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b9e43a5e660> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#    turbidity: acc=0.949  prec=0.957  recall=0.938  f1=0.947
#     particle: acc=1.000  prec=1.000  recall=1.000  f1=1.000
#       colour: acc=1.000  prec=1.000  recall=1.000  f1=1.000
ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0206 - loss: 0.1993 - particle_accuracy: 0.9966 - particle_loss: 0.0138 - turbidity_accuracy: 0.9257 - turbidity_loss: 0.1665
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - colour_accuracy: 0.9899 - colour_loss: 0.0432 - loss: 0.2331 - particle_accuracy: 0.9966 - particle_loss: 0.0111 - turbidity_accuracy: 0.9291 - turbidity_loss: 0.1796
# Final model kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.keras

# %%
# # ── 8. Training curve ─────────────────────────────────────────────
# import matplotlib.pyplot as plt

# fig, axes = plt.subplots(1, 4, figsize=(22, 4))
# metrics = [
#     ('loss',                'Total loss'),
#     ('turbidity_accuracy',  'Turbidity acc'),
#     ('particle_accuracy',   'Particle acc'),
#     ('colour_accuracy',     'Colour acc'),
# ]
# for ax, (metric, title) in zip(axes, metrics):
#     ax.plot(history.history[metric], label='train')
#     ax.plot(history.history[f'val_{metric}'], label='val')
#     ax.set_title(title)
#     ax.legend()
# plt.tight_layout()
# plt.savefig('/content/training_curves.png', dpi=120)
# plt.show()
from sklearn.metrics import confusion_matrix

print(f'══════ {N_FOLDS}-fold CV — ortalama ± std (threshold=0.5) ══════')
print(f'{"Label":>10} | {"Accuracy":>15} | {"Precision":>15} | {"Recall":>15} | {"F1":>15}')
print('-' * 88)
for k in ['turbidity', 'particle', 'colour']:
    accs  = [r[k]['acc']    for r in fold_results]
    precs = [r[k]['prec']   for r in fold_results]
    recs  = [r[k]['recall'] for r in fold_results]
    f1s   = [r[k]['f1']     for r in fold_results]
    print(f'{k:>10s} | {np.mean(accs):.3f} ± {np.std(accs):.3f} | '
          f'{np.mean(precs):.3f} ± {np.std(precs):.3f} | '
          f'{np.mean(recs):.3f} ± {np.std(recs):.3f} | '
          f'{np.mean(f1s):.3f} ± {np.std(f1s):.3f}')

print(f'\n══════ Per-fold detay ══════')
for fi, r in enumerate(fold_results):
    print(f'\nFold {fi+1}:')
    for k in ['turbidity', 'particle', 'colour']:
        m = r[k]
        print(f'  {k:>10s}: acc={m["acc"]:.3f}  prec={m["prec"]:.3f}  '
              f'recall={m["recall"]:.3f}  f1={m["f1"]:.3f}')

print(f'\n══════ Confusion Matrix (pooled, threshold=0.5) ══════')
for k in ['turbidity', 'particle', 'colour']:
    y_true_all, sc_all = zip(*fold_scores[k])
    yp = [1 if s > 0.5 else 0 for s in sc_all]
    cm = confusion_matrix(y_true_all, yp)
    tn, fp, fn, tp = cm.ravel()
    print(f'\n── {k} ──')
    print(f'                 Pred 0   Pred 1')
    print(f'    Actual 0:    {tn:>6}   {fp:>6}   (TN, FP)')
    print(f'    Actual 1:    {fn:>6}   {tp:>6}   (FN, TP)')
# Out:
# ══════ 3-fold CV — ortalama ± std (threshold=0.5) ══════
#      Label |        Accuracy |       Precision |          Recall |              F1
# ----------------------------------------------------------------------------------------
#  turbidity | 0.922 ± 0.021 | 0.934 ± 0.019 | 0.902 ± 0.027 | 0.918 ± 0.023
#   particle | 0.997 ± 0.005 | 1.000 ± 0.000 | 0.993 ± 0.010 | 0.996 ± 0.005
#     colour | 0.983 ± 0.013 | 0.987 ± 0.019 | 0.979 ± 0.017 | 0.983 ± 0.013
#
# ══════ Per-fold detay ══════
#
# Fold 1:
#    turbidity: acc=0.949  prec=0.957  recall=0.938  f1=0.947
#     particle: acc=1.000  prec=1.000  recall=1.000  f1=1.000
#       colour: acc=1.000  prec=1.000  recall=1.000  f1=1.000
#
# Fold 2:
#    turbidity: acc=0.919  prec=0.935  recall=0.896  f1=0.915
#     particle: acc=0.990  prec=1.000  recall=0.979  f1=0.989
#       colour: acc=0.970  prec=0.960  recall=0.980  f1=0.970
#
# Fold 3:
#    turbidity: acc=0.898  prec=0.911  recall=0.872  f1=0.891
#     particle: acc=1.000  prec=1.000  recall=1.000  f1=1.000
#       colour: acc=0.980  prec=1.000  recall=0.958  f1=0.979
#
# ══════ Confusion Matrix (pooled, threshold=0.5) ══════
#
# ── turbidity ──
#                  Pred 0   Pred 1
#     Actual 0:       144        9   (TN, FP)
#     Actual 1:        14      129   (FN, TP)
#
# ── particle ──
#                  Pred 0   Pred 1
#     Actual 0:       153        0   (TN, FP)
#     Actual 1:         1      142   (FN, TP)
#
# ── colour ──
#                  Pred 0   Pred 1
#     Actual 0:       149        2   (TN, FP)
#     Actual 1:         3      142   (FN, TP)

# %%
# ── 9. Test seti değerlendirme ────────────────────────────────────
best_model = tf.keras.models.load_model(SAVE_PATH)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

y_true = {'turbidity': [], 'particle': [], 'colour': []}
y_pred = {'turbidity': [], 'particle': [], 'colour': []}
scores = {'turbidity': [], 'particle': [], 'colour': []}

for imgs, labels in test_ds:
    preds = best_model.predict(imgs, verbose=0)
    for key in ['turbidity', 'particle', 'colour']:
        y_true[key].extend(labels[key].numpy().flatten())
        scores[key].extend(preds[key].flatten())
        y_pred[key].extend((preds[key] > 0.5).flatten().astype(int))

for key in ['turbidity', 'particle', 'colour']:
    acc = accuracy_score(y_true[key], y_pred[key])
    f1  = f1_score(y_true[key], y_pred[key], zero_division=0)
    cm  = confusion_matrix(y_true[key], y_pred[key])
    sc  = scores[key]
    print(f'\n── {key} ──')
    print(f'  Accuracy : {acc:.4f}')
    print(f'  F1 Score : {f1:.4f}')
    print(f'  Score min/max/mean: {min(sc):.3f} / {max(sc):.3f} / {np.mean(sc):.3f}')
    print(f'  Confusion matrix:\n{cm}')
# Out:
# ── turbidity ──
#   Accuracy : 0.8667
#   F1 Score : 0.8333
#   Score min/max/mean: 0.000 / 1.000 / 0.348
#   Confusion matrix:
# [[24  0]
#  [ 6 15]]
#
# ── particle ──
#   Accuracy : 1.0000
#   F1 Score : 1.0000
#   Score min/max/mean: 0.000 / 1.000 / 0.474
#   Confusion matrix:
# [[24  0]
#  [ 0 21]]
#
# ── colour ──
#   Accuracy : 0.9556
#   F1 Score : 0.9524
#   Score min/max/mean: 0.001 / 1.000 / 0.486
#   Confusion matrix:
# [[23  0]
#  [ 2 20]]

# %%
# # ── 10. Optimal threshold ─────────────────────────────────────────
# for key in ['turbidity', 'particle', 'colour']:
#     best_t, best_f1 = 0.5, 0
#     for thresh in np.arange(0.05, 0.95, 0.05):
#         yp = [1 if s > thresh else 0 for s in scores[key]]
#         f1 = f1_score(y_true[key], yp, zero_division=0)
#         if f1 > best_f1:
#             best_f1 = f1
#             best_t  = thresh
#     yp_best = [1 if s > best_t else 0 for s in scores[key]]
#     acc = accuracy_score(y_true[key], yp_best)
#     print(f'{key}: best_threshold={best_t:.2f}  acc={acc:.3f}  f1={best_f1:.3f}')
# ── 10. Optimal threshold + metrikler (pooled val) ────────────────
print(f'══════ Optimal threshold (F1 maksimum) ══════\n')
for k in ['turbidity', 'particle', 'colour']:
    y_true_all, sc_all = zip(*fold_scores[k])
    best_t, best_f1 = 0.5, 0
    for t in np.arange(0.05, 0.95, 0.05):
        yp = [1 if s > t else 0 for s in sc_all]
        f1 = f1_score(y_true_all, yp, zero_division=0)
        if f1 > best_f1:
            best_f1, best_t = f1, t

    yp_best = [1 if s > best_t else 0 for s in sc_all]
    acc  = accuracy_score(y_true_all, yp_best)
    prec = precision_score(y_true_all, yp_best, zero_division=0)
    rec  = recall_score(y_true_all, yp_best, zero_division=0)
    cm   = confusion_matrix(y_true_all, yp_best)
    tn, fp, fn, tp = cm.ravel()
    print(f'── {k} ──')
    print(f'  threshold = {best_t:.2f}')
    print(f'  acc={acc:.3f}  prec={prec:.3f}  recall={rec:.3f}  f1={best_f1:.3f}')
    print(f'  Confusion Matrix:')
    print(f'                 Pred 0   Pred 1')
    print(f'    Actual 0:    {tn:>6}   {fp:>6}')
    print(f'    Actual 1:    {fn:>6}   {tp:>6}\n')
# Out:
# ══════ Optimal threshold (F1 maksimum) ══════
#
# ── turbidity ──
#   threshold = 0.60
#   acc=0.932  prec=0.962  recall=0.895  f1=0.928
#   Confusion Matrix:
#                  Pred 0   Pred 1
#     Actual 0:       148        5
#     Actual 1:        15      128
#
# ── particle ──
#   threshold = 0.25
#   acc=1.000  prec=1.000  recall=1.000  f1=1.000
#   Confusion Matrix:
#                  Pred 0   Pred 1
#     Actual 0:       153        0
#     Actual 1:         0      143
#
# ── colour ──
#   threshold = 0.55
#   acc=0.990  prec=1.000  recall=0.979  f1=0.990
#   Confusion Matrix:
#                  Pred 0   Pred 1
#     Actual 0:       151        0
#     Actual 1:         3      142

# %%
# from PIL import Image
# import numpy as np
# import glob, os

# best_model = tf.keras.models.load_model(SAVE_PATH)

# images = sorted(glob.glob('/content/test_images/*.jpg') + glob.glob('/content/test_images/*.jpeg'))

# if not images:
#     print('Görüntü bulunamadı — /content/*.jpg formatında kaydet')
# else:
#     print(f"{'Dosya':<30} {'Contamination':>15} {'Colour':>10} {'Karar'}")
#     print('-' * 70)
#     for path in images:
#         img = Image.open(path).convert('RGB').resize((192, 192))
#         arr = np.expand_dims(np.array(img, dtype=np.float32) / 255.0, axis=0)
#         preds = best_model.predict(arr, verbose=0)
#         cont  = float(preds[0][0][0])
#         col   = float(preds[1][0][0])
#         karar = []
#         if cont > 0.25: karar.append('KİRLİ')
#         if col  > 0.05: karar.append('RENKLİ')
#         if not karar:   karar.append('TEMİZ')
#         fname = os.path.basename(path)
#         print(f'{fname:<30} {cont:>15.4f} {col:>10.4f}  {", ".join(karar)}')

# %%
# ── TFLite INT8 dönüşümü ──────────────────────────────────────────
import tensorflow as tf

# En iyi modeli Drive'dan yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

TFLITE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.tflite'

def representative_dataset():
    for imgs, _ in train_ds:
        yield [imgs]

converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.float32  # çıkış float32 — hassasiyet kaybı önlenir

tflite_model = converter.convert()

with open(TFLITE_PATH, 'wb') as f:
    f.write(tflite_model)

print(f'Model boyutu: {len(tflite_model)/1024:.1f} KB')
print(f'Kaydedildi: {TFLITE_PATH}')

# Tensor sırasını kontrol et
interpreter = tf.lite.Interpreter(model_path=TFLITE_PATH)
interpreter.allocate_tensors()
output_details = interpreter.get_output_details()
for i, o in enumerate(output_details):
    print(f'[{i}] {o["name"]}  dtype={o["dtype"]}')
# Out:
# Saved artifact at '/tmp/tmphvjkwkeo'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   Dict[['turbidity', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)], ['particle', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)], ['colour', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]]
# Captures:
#   135919576594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919576585936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919611477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605645584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605646736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605646160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605647312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605645392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605648272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605647696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605647888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605648080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605645968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605649232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605648656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605648848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605649040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605649616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605649808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605651152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605648464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605652112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605651536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605651728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605651920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605649424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605653072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605652496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605652688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605652880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605650384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605653456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605653648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605653840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605651344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605652304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605655952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605655376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605655568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605655760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605653264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605656912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605656336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605656528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605656720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605654224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605657872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605657296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605657488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605657680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605655184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605658832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605658256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605658448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605658640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605656144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605657104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605660176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605660368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605661520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605660944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605661136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919605658064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606465360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606464976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606464592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606470160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606470928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606470544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919606477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565340752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565340944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565341136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565342672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565342096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565342288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565342480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565341520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565343632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565343056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565343248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565343440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565341712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565341904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565345552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565345168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565342864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565346512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565345936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565346128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565343824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565347472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565346896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565347088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565347280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565344784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565348432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565347856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565348048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565348240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565345744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565348816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565346704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565350352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565350160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565347664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565351312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565350736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565350928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565351120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565348624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565352272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565351696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565351888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565352080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565349584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565353232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565352656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565352848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565353040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565350544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565354192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565353616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565353808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565354000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565351504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565355152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565354576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565354768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565354960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565352464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565356112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565355536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565355728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565355344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565356880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565356304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565356496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565355920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919607318480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919607318288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919607318096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919607317136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919565353424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135919607316560: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Model boyutu: 772.6 KB
# Kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.tflite
# [0] StatefulPartitionedCall_1:1  dtype=<class 'numpy.float32'>
# [1] StatefulPartitionedCall_1:2  dtype=<class 'numpy.float32'>
# [2] StatefulPartitionedCall_1:0  dtype=<class 'numpy.float32'>
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# import numpy as np
# from PIL import Image
# import tensorflow as tf
# best_model = tf.keras.models.load_model(SAVE_PATH)
# # JPEG'i aç ama önce uint8 array'e çevir, sonra float yap
# img = Image.open("/content/con8633co1719.jpeg").convert("RGB")
# arr_uint8 = np.array(img, dtype=np.uint8)
# # uint8 direkt — ESP32'nin yaptığı gibi
# arr_float = np.expand_dims(arr_uint8.astype(np.float32) / 255.0, axis=0)
# preds = best_model.predict(arr_float, verbose=0)
# print(f"contamination: {preds[0][0][0]:.4f}")
# print(f"colour:        {preds[1][0][0]:.4f}")
# # Ayrıca TFLite ile de test et
# interpreter = tf.lite.Interpreter(model_path="/content/drive/MyDrive/wco_model_v7_int8.tflite")
# interpreter.allocate_tensors()
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()
# img_uint8 = np.expand_dims(arr_uint8, axis=0)
# interpreter.set_tensor(input_details[0]['index'], img_uint8)
# interpreter.invoke()
# raw0 = interpreter.get_tensor(output_details[0]['index'])[0][0]
# raw1 = interpreter.get_tensor(output_details[1]['index'])[0][0]
# scale = output_details[0]['quantization'][0]
# print(f"\nTFLite [0]: {int(raw0) * scale:.4f}")
# print(f"TFLite [1]: {int(raw1) * scale:.4f}")

# %%
# !xxd -i /content/drive/MyDrive/models/MobileNetV2_a035.tflite > /content/drive/MyDrive/models/MobileNetV2_a035.cpp

# %%
# with open('/content/drive/MyDrive/models/MobileNetV2_a035.cpp', 'r') as f:
#     content = f.read()

# content = (
#       '#include "MobileNetV1_a025.h"\n\n'
#       '#ifdef __has_attribute\n#define HAVE_ATTRIBUTE(x) __has_attribute(x)\n'
#       '#else\n#define HAVE_ATTRIBUTE(x) 0\n#endif\n'
#       '#if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))\n'
#       '#define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))\n'
#       '#else\n#define DATA_ALIGN_ATTRIBUTE\n#endif\n\n'
#       + content
#       .replace('unsigned char wco_model_v2_int8_tflite[]',
#                'const unsigned char g_wco_model_v2_data[] DATA_ALIGN_ATTRIBUTE')
#       .replace('unsigned int _content_drive_MyDrive_wco_model_v7_int8_tflite_len',
#                'const int g_wco_model_v2_data_len')
#   )

# with open('/content/wco_model_data.cpp', 'w') as f:
#       f.write(content)

# print('Hazır:', '/content/wco_model_data.cpp')
