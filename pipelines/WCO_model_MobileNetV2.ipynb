# %% [markdown]
# # WCO Model MobileNetV2 -> alpha = 0.35 -> 160x160
# **Output:** contamination + colour
# **Inference:** FastAPI server (Keras float32)
# **ESP32:** sadece görüntü toplar, inference yok

# %%
# ── 1. Drive mount ────────────────────────────────────────────────
import os
from google.colab import drive

drive.mount('/content/drive')

DRIVE_DIR = '/content/drive/MyDrive/cropped160'
SAVE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.keras'

os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ── 2. Import ─────────────────────────────────────────────────────
import os, re
import numpy as np
import tensorflow as tf
import keras
from keras import layers, Model
from keras.applications import MobileNetV2
from sklearn.model_selection import train_test_split

IMG_SIZE   = 160
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE

print('TF version:', tf.__version__)
# Out:
# TF version: 2.19.0

# %%
# ── 3. Label parse ────────────────────────────────────────────────
# contamination = min(1, turbidity + particle)
# colour ayrı kalır
def parse_label(filename):
    m = re.match(r't(\d)[_-]p(\d)[_-]c(\d)', filename)
    if not m:
        return None
    t, p, c = int(m.group(1)), int(m.group(2)), int(m.group(3))
    contamination = min(1, t + p)
    return np.array([contamination, c], dtype=np.float32)

all_files, all_labels = [], []

for fname in sorted(os.listdir(DRIVE_DIR)):
    if not (fname.endswith('.jpg') or fname.endswith('.jpeg')):
        continue

    lbl = parse_label(fname)
    if lbl is None:
        print(f'SKIP: {fname}')
        continue
    all_files.append(os.path.join(DRIVE_DIR, fname))
    all_labels.append(lbl)

all_labels = np.array(all_labels, dtype=np.float32)
print(f'Toplam        : {len(all_files)} görüntü')
print(f'contamination : {all_labels[:,0].sum():.0f} pozitif')
print(f'colour        : {all_labels[:,1].sum():.0f} pozitif')
# Out:
# Toplam        : 296 görüntü
# contamination : 216 pozitif
# colour        : 145 pozitif

# %%
# ── 4. Train / val / test split ───────────────────────────────────
label_keys = [''.join(map(str, l.astype(int))) for l in all_labels]

files_train, files_temp, y_train, y_temp = train_test_split(
    all_files, all_labels,
    test_size=0.30, stratify=label_keys, random_state=42
)
label_keys_temp = [''.join(map(str, l.astype(int))) for l in y_temp]
files_val, files_test, y_val, y_test = train_test_split(
    files_temp, y_temp,
    test_size=0.50, stratify=label_keys_temp, random_state=42
)

print(f'Train : {len(files_train)}')
print(f'Val   : {len(files_val)}')
print(f'Test  : {len(files_test)}')
# Out:
# Train : 207
# Val   : 44
# Test  : 45

# %%
# ── 5. tf.data pipeline ───────────────────────────────────────────
augment = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.08),
], name='augmentation')

def load_train(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.keras.applications.mobilenet_v2.preprocess_input(img)  # düzeltildi
    img = augment(img, training=True)
    return img, {'contamination': label[0:1], 'colour': label[1:2]}

def load_eval(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.keras.applications.mobilenet_v2.preprocess_input(img)  # düzeltildi
    return img, {'contamination': label[0:1], 'colour': label[1:2]}

train_ds = (tf.data.Dataset.from_tensor_slices((files_train, y_train))
            .shuffle(len(files_train), seed=42)
            .map(load_train, num_parallel_calls=AUTOTUNE)
            .batch(BATCH_SIZE).prefetch(AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((files_val, y_val))
          .map(load_eval, num_parallel_calls=AUTOTUNE)
          .batch(BATCH_SIZE).prefetch(AUTOTUNE))

test_ds = (tf.data.Dataset.from_tensor_slices((files_test, y_test))
           .map(load_eval, num_parallel_calls=AUTOTUNE)
           .batch(BATCH_SIZE).prefetch(AUTOTUNE))

print('Pipeline hazır')
# Out:
# Pipeline hazır

# %%
# ── 6. Model ──────────────────────────────────────────────────────
def build_model():
    backbone = MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        alpha=0.35,
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    out_cont = layers.Dense(1, activation='sigmoid', name='contamination')(x)
    out_c    = layers.Dense(1, activation='sigmoid', name='colour')(x)

    model = Model(inputs=inputs, outputs=[out_cont, out_c])
    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={'contamination': 'binary_crossentropy', 'colour': 'binary_crossentropy'},
        metrics={'contamination': ['accuracy'], 'colour': ['accuracy']}
    )
    return model

model = build_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_0.35_1… │ (None, 5, 5,      │    410,208 │ input_layer_2[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_0.35… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ contamination       │ (None, 1)         │        129 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ colour (Dense)      │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 574,434 (2.19 MB)
#  Trainable params: 164,226 (641.51 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %%
# ── 7. Eğitim ─────────────────────────────────────────────────────
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=7, restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        SAVE_PATH, monitor='val_loss', save_best_only=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6
    ),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

print(f'\nEn iyi model kaydedildi: {SAVE_PATH}')
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 527ms/step - colour_accuracy: 0.7681 - colour_loss: 0.4372 - contamination_accuracy: 0.8068 - contamination_loss: 0.4433 - loss: 0.8825 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.2397 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.1335 - val_loss: 0.3723 - learning_rate: 0.0010
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - colour_accuracy: 0.9517 - colour_loss: 0.1864 - contamination_accuracy: 0.9082 - contamination_loss: 0.2482 - loss: 0.4342 - val_colour_accuracy: 0.9318 - val_colour_loss: 0.1259 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.1036 - val_loss: 0.2271 - learning_rate: 0.0010
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - colour_accuracy: 0.9662 - colour_loss: 0.1333 - contamination_accuracy: 0.9179 - contamination_loss: 0.1677 - loss: 0.3008 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0841 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0858 - val_loss: 0.1684 - learning_rate: 0.0010
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - colour_accuracy: 0.9758 - colour_loss: 0.0941 - contamination_accuracy: 0.9179 - contamination_loss: 0.1942 - loss: 0.2868 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0886 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0694 - val_loss: 0.1552 - learning_rate: 0.0010
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - colour_accuracy: 0.9758 - colour_loss: 0.0713 - contamination_accuracy: 0.9275 - contamination_loss: 0.1659 - loss: 0.2363 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0704 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0830 - val_loss: 0.1549 - learning_rate: 0.0010
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0528 - contamination_accuracy: 0.9517 - contamination_loss: 0.1235 - loss: 0.1767 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0661 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0784 - val_loss: 0.1440 - learning_rate: 0.0010
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - colour_accuracy: 0.9952 - colour_loss: 0.0538 - contamination_accuracy: 0.9662 - contamination_loss: 0.1187 - loss: 0.1725 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0502 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0661 - val_loss: 0.1169 - learning_rate: 0.0010
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0433 - contamination_accuracy: 0.9420 - contamination_loss: 0.1109 - loss: 0.1548 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0473 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0553 - val_loss: 0.1021 - learning_rate: 0.0010
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0368 - contamination_accuracy: 0.9710 - contamination_loss: 0.0796 - loss: 0.1153 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0438 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0705 - val_loss: 0.1138 - learning_rate: 0.0010
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - colour_accuracy: 0.9952 - colour_loss: 0.0294 - contamination_accuracy: 0.9565 - contamination_loss: 0.1141 - loss: 0.1436 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0370 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0619 - val_loss: 0.1009 - learning_rate: 0.0010
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0351 - contamination_accuracy: 0.9758 - contamination_loss: 0.0755 - loss: 0.1109 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0480 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0638 - val_loss: 0.1120 - learning_rate: 0.0010
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0386 - contamination_accuracy: 0.9758 - contamination_loss: 0.0690 - loss: 0.1079 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0353 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0648 - val_loss: 0.1024 - learning_rate: 0.0010
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0279 - contamination_accuracy: 0.9614 - contamination_loss: 0.0987 - loss: 0.1264 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0283 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0951 - val_loss: 0.1275 - learning_rate: 0.0010
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - colour_accuracy: 0.9952 - colour_loss: 0.0221 - contamination_accuracy: 0.9517 - contamination_loss: 0.0904 - loss: 0.1126 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0368 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0625 - val_loss: 0.1025 - learning_rate: 5.0000e-04
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0154 - contamination_accuracy: 0.9758 - contamination_loss: 0.0760 - loss: 0.0910 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0276 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0483 - val_loss: 0.0786 - learning_rate: 5.0000e-04
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0236 - contamination_accuracy: 0.9855 - contamination_loss: 0.0546 - loss: 0.0782 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0271 - val_contamination_accuracy: 0.9318 - val_contamination_loss: 0.0764 - val_loss: 0.1055 - learning_rate: 5.0000e-04
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0173 - contamination_accuracy: 0.9807 - contamination_loss: 0.0591 - loss: 0.0765 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0337 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0490 - val_loss: 0.0845 - learning_rate: 5.0000e-04
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0146 - contamination_accuracy: 0.9758 - contamination_loss: 0.0762 - loss: 0.0909 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0313 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0494 - val_loss: 0.0823 - learning_rate: 5.0000e-04
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - colour_accuracy: 0.9952 - colour_loss: 0.0179 - contamination_accuracy: 0.9952 - contamination_loss: 0.0359 - loss: 0.0539 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0298 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0625 - val_loss: 0.0938 - learning_rate: 2.5000e-04
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0128 - contamination_accuracy: 0.9903 - contamination_loss: 0.0495 - loss: 0.0624 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0309 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0583 - val_loss: 0.0915 - learning_rate: 2.5000e-04
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - colour_accuracy: 0.9952 - colour_loss: 0.0138 - contamination_accuracy: 0.9807 - contamination_loss: 0.0461 - loss: 0.0600 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0330 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0531 - val_loss: 0.0884 - learning_rate: 2.5000e-04
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0123 - contamination_accuracy: 0.9758 - contamination_loss: 0.0493 - loss: 0.0617 - val_colour_accuracy: 0.9773 - val_colour_loss: 0.0350 - val_contamination_accuracy: 0.9773 - val_contamination_loss: 0.0541 - val_loss: 0.0914 - learning_rate: 1.2500e-04
#
# En iyi model kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.keras

# %%
# ── 8. Training curve ─────────────────────────────────────────────
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 4))
for ax, metric in zip(axes, ['loss', 'contamination_accuracy', 'colour_accuracy']):
    ax.plot(history.history[metric], label='train')
    ax.plot(history.history[f'val_{metric}'], label='val')
    ax.set_title(metric)
    ax.legend()
plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=120)
plt.show()

# %%
# ── 9. Test seti değerlendirme ────────────────────────────────────
# Drive'daki kaydedilen en iyi modeli yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

y_true_cont, y_true_c = [], []
y_pred_cont, y_pred_c = [], []
scores_cont, scores_c = [], []

for imgs, labels in test_ds:
    preds = best_model.predict(imgs, verbose=0)
    y_true_cont.extend(labels['contamination'].numpy().flatten())
    y_true_c.extend(labels['colour'].numpy().flatten())
    scores_cont.extend(preds[0].flatten())
    scores_c.extend(preds[1].flatten())
    y_pred_cont.extend((preds[0] > 0.5).flatten())
    y_pred_c.extend((preds[1] > 0.5).flatten())

for name, yt, yp, sc in [
    ('contamination', y_true_cont, y_pred_cont, scores_cont),
    ('colour',        y_true_c,    y_pred_c,    scores_c)
]:
    acc = accuracy_score(yt, yp)
    f1  = f1_score(yt, yp, zero_division=0)
    cm  = confusion_matrix(yt, yp)
    print(f'\n── {name} ──')
    print(f'  Accuracy : {acc:.4f}')
    print(f'  F1 Score : {f1:.4f}')
    print(f'  Score min/max/mean: {min(sc):.3f} / {max(sc):.3f} / {np.mean(sc):.3f}')
    print(f'  Confusion matrix:\n{cm}')
# Out:
# ── contamination ──
#   Accuracy : 0.9333
#   F1 Score : 0.9538
#   Score min/max/mean: 0.007 / 1.000 / 0.726
#   Confusion matrix:
# [[11  1]
#  [ 2 31]]
#
# ── colour ──
#   Accuracy : 1.0000
#   F1 Score : 1.0000
#   Score min/max/mean: 0.000 / 1.000 / 0.489
#   Confusion matrix:
# [[23  0]
#  [ 0 22]]

# %%
# ── 10. Optimal threshold ─────────────────────────────────────────
for name, yt, sc in [
    ('contamination', y_true_cont, scores_cont),
    ('colour',        y_true_c,    scores_c)
]:
    best_t, best_f1 = 0.5, 0
    for thresh in np.arange(0.05, 0.95, 0.05):
        yp = [1 if s > thresh else 0 for s in sc]
        f1 = f1_score(yt, yp, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_t  = thresh
    yp_best = [1 if s > best_t else 0 for s in sc]
    acc = accuracy_score(yt, yp_best)
    print(f'{name}: best_threshold={best_t:.2f}  acc={acc:.3f}  f1={best_f1:.3f}')
# Out:
# contamination: best_threshold=0.55  acc=0.956  f1=0.969
# colour: best_threshold=0.10  acc=1.000  f1=1.000

# %%
from PIL import Image
import numpy as np
import glob, os

best_model = tf.keras.models.load_model(SAVE_PATH)

images = sorted(glob.glob('/content/test_images/*.jpg') + glob.glob('/content/test_images/*.jpeg'))

if not images:
    print('Görüntü bulunamadı — /content/*.jpg formatında kaydet')
else:
    print(f"{'Dosya':<30} {'Contamination':>15} {'Colour':>10} {'Karar'}")
    print('-' * 70)
    for path in images:
        img = Image.open(path).convert('RGB').resize((192, 192))
        arr = np.expand_dims(np.array(img, dtype=np.float32) / 255.0, axis=0)
        preds = best_model.predict(arr, verbose=0)
        cont  = float(preds[0][0][0])
        col   = float(preds[1][0][0])
        karar = []
        if cont > 0.25: karar.append('KİRLİ')
        if col  > 0.05: karar.append('RENKLİ')
        if not karar:   karar.append('TEMİZ')
        fname = os.path.basename(path)
        print(f'{fname:<30} {cont:>15.4f} {col:>10.4f}  {", ".join(karar)}')
# Out:
# Görüntü bulunamadı — /content/*.jpg formatında kaydet

# %%
# ── TFLite INT8 dönüşümü ──────────────────────────────────────────
import tensorflow as tf

# En iyi modeli Drive'dan yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

TFLITE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.tflite'

def representative_dataset():
    for imgs, _ in train_ds:
        yield [imgs]

converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

tflite_model = converter.convert()

with open(TFLITE_PATH, 'wb') as f:
    f.write(tflite_model)

print(f'Model boyutu: {len(tflite_model)/1024:.1f} KB')
print(f'Kaydedildi: {TFLITE_PATH}')

# Tensor sırasını kontrol et
interpreter = tf.lite.Interpreter(model_path=TFLITE_PATH)
interpreter.allocate_tensors()
output_details = interpreter.get_output_details()
for i, o in enumerate(output_details):
    print(f'[{i}] {o["name"]}  dtype={o["dtype"]}')
# Out:
# Saved artifact at '/tmp/tmp5t2masqk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]
# Captures:
#   136709549521808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549522768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549521232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549519888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549519504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549522384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549520080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549519120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549521040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549519696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549519312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549518160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549518736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549518544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549518352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549517968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709549518928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625202448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625201680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625201104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625200912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625202064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625201872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625202832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625200720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625204176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625201296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625205328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625204752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625204944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625205136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625202640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625205712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625205904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625203600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625207248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625206672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625206864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625204560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625207632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625207824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625205520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625206480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625209744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625207440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625211088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625210512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625210704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625208400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625211472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625211664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625211856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625209360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625212432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625212624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625212816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625210320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625211280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625214928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625214352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625214544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625214736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625212240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625215888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625215312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625215504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625216272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625213200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625216848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625215696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625216464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625216656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625216080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709625215120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557159504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557159696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557158160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557159312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557160080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557160272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557160464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557161616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557161424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557159888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557163536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557163152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557163344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557160848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557164496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557163920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557164112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557164304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557161808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557165456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557165072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557165264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557162768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557165840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557163728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557167376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557167184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557164688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557168336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557167760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557167952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557168144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557165648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557169296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557168720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557168912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557169104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557166608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557170256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557169872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557170064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557167568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557170640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557170832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557168528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557169488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557173136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557172560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557172752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557173520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557170448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557174096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557172944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557171408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557173904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136709557172368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171887184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171885840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171888336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171887760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171887952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171888144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171889296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171888720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171888912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171886224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171890256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171889680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171889872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171890064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171887568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171890640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171890832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171892176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171893136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171892560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171892752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171892944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171890448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171894096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171893520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171893712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171893904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171891408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171895056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171894480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171894672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171892368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171895440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171895632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171895824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171893328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171894288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171897936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171897552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171897744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171898896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171897168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171900432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171899280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171898512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136710171898128: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Model boyutu: 772.2 KB
# Kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.tflite
# [0] StatefulPartitionedCall_1:1  dtype=<class 'numpy.uint8'>
# [1] StatefulPartitionedCall_1:0  dtype=<class 'numpy.uint8'>
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
import numpy as np
from PIL import Image
import tensorflow as tf
best_model = tf.keras.models.load_model(SAVE_PATH)
# JPEG'i aç ama önce uint8 array'e çevir, sonra float yap
img = Image.open("/content/con8633co1719.jpeg").convert("RGB")
arr_uint8 = np.array(img, dtype=np.uint8)
# uint8 direkt — ESP32'nin yaptığı gibi
arr_float = np.expand_dims(arr_uint8.astype(np.float32) / 255.0, axis=0)
preds = best_model.predict(arr_float, verbose=0)
print(f"contamination: {preds[0][0][0]:.4f}")
print(f"colour:        {preds[1][0][0]:.4f}")
# Ayrıca TFLite ile de test et
interpreter = tf.lite.Interpreter(model_path="/content/drive/MyDrive/wco_model_v7_int8.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
img_uint8 = np.expand_dims(arr_uint8, axis=0)
interpreter.set_tensor(input_details[0]['index'], img_uint8)
interpreter.invoke()
raw0 = interpreter.get_tensor(output_details[0]['index'])[0][0]
raw1 = interpreter.get_tensor(output_details[1]['index'])[0][0]
scale = output_details[0]['quantization'][0]
print(f"\nTFLite [0]: {int(raw0) * scale:.4f}")
print(f"TFLite [1]: {int(raw1) * scale:.4f}")
# Out:
# contamination: 0.9766
# colour:        0.9713
#
# TFLite [0]: 0.9922
# TFLite [1]: 0.9219

# %%
# !xxd -i /content/drive/MyDrive/models/MobileNetV2_a035.tflite > /content/drive/MyDrive/models/MobileNetV2_a035.cpp

# %%
with open('/content/drive/MyDrive/models/MobileNetV2_a035.cpp', 'r') as f:
    content = f.read()

content = (
      '#include "MobileNetV1_a025.h"\n\n'
      '#ifdef __has_attribute\n#define HAVE_ATTRIBUTE(x) __has_attribute(x)\n'
      '#else\n#define HAVE_ATTRIBUTE(x) 0\n#endif\n'
      '#if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))\n'
      '#define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))\n'
      '#else\n#define DATA_ALIGN_ATTRIBUTE\n#endif\n\n'
      + content
      .replace('unsigned char wco_model_v2_int8_tflite[]',
               'const unsigned char g_model_int8_data[] DATA_ALIGN_ATTRIBUTE')
      .replace('unsigned int _content_drive_MyDrive_wco_model_v7_int8_tflite_len',
               'const int g_model_int8_data_len')
  )

with open('/content/wco_model_data.cpp', 'w') as f:
      f.write(content)

print('Hazır:', '/content/wco_model_data.cpp')
# Out:
# Hazır: /content/wco_model_data.cpp
