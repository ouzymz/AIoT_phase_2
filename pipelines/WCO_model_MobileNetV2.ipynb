# %% [markdown]
# # WCO Model MobileNetV2 -> alpha = 0.35 -> 160x160
# **Output:** contamination + colour
# **Inference:** FastAPI server (Keras float32)
# **ESP32:** sadece görüntü toplar, inference yok

# %%
# ── 1. Drive mount ────────────────────────────────────────────────
import os
from google.colab import drive

drive.mount('/content/drive')

DRIVE_DIR = '/content/drive/MyDrive/cropped160'
SAVE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.keras'

os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ── 2. Import ─────────────────────────────────────────────────────
import os, re
import numpy as np
import tensorflow as tf
import keras
from keras import layers, Model
from keras.applications import MobileNetV2
from sklearn.model_selection import train_test_split

IMG_SIZE   = 160
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE

print('TF version:', tf.__version__)
# Out:
# TF version: 2.19.0

# %%
# ── 3. Label parse ────────────────────────────────────────────────
# contamination = min(1, turbidity + particle)
# colour ayrı kalır
def parse_label(filename):
    m = re.match(r't(\d)[_-]p(\d)[_-]c(\d)', filename)
    if not m:
        return None
    t, p, c = int(m.group(1)), int(m.group(2)), int(m.group(3))
    return np.array([t, p, c], dtype=np.float32)

all_files, all_labels = [], []

for fname in sorted(os.listdir(DRIVE_DIR)):
    if not (fname.endswith('.jpg') or fname.endswith('.jpeg')):
        continue

    lbl = parse_label(fname)
    if lbl is None:
        print(f'SKIP: {fname}')
        continue
    all_files.append(os.path.join(DRIVE_DIR, fname))
    all_labels.append(lbl)

all_labels = np.array(all_labels, dtype=np.float32)
print(f'Toplam        : {len(all_files)} görüntü')
print(f'turbidity   : {all_labels[:,0].sum():.0f} pozitif')
print(f'particle    : {all_labels[:,1].sum():.0f} pozitif')
print(f'colour      : {all_labels[:,2].sum():.0f} pozitif')
# Out:
# Toplam        : 296 görüntü
# turbidity   : 143 pozitif
# particle    : 143 pozitif
# colour      : 145 pozitif

# %%
# ── 4. Train / val / test split ───────────────────────────────────
# Stratify: colour (en az varyans)
colour_buckets = all_labels[:, 2].astype(int)

files_train, files_temp, y_train, y_temp = train_test_split(
    all_files, all_labels,
    test_size=0.30, stratify=colour_buckets, random_state=42
)
colour_buckets_temp = y_temp[:, 2].astype(int)
files_val, files_test, y_val, y_test = train_test_split(
    files_temp, y_temp,
    test_size=0.50, stratify=colour_buckets_temp, random_state=42
)

print(f'Train : {len(files_train)}')
print(f'Val   : {len(files_val)}')
print(f'Test  : {len(files_test)}')
# Out:
# Train : 207
# Val   : 44
# Test  : 45

# %%
# ── 5. tf.data pipeline ───────────────────────────────────────────
augment = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.08),
], name='augmentation')

def load_train(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0  # [0,1] — uint8 input ile uyumlu
    return img, {
        'turbidity': label[0:1],
        'particle':  label[1:2],
        'colour':    label[2:3],
    }

def load_eval(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0  # [0,1] — uint8 input ile uyumlu
    return img, {
        'turbidity': label[0:1],
        'particle':  label[1:2],
        'colour':    label[2:3],
    }

train_ds = (tf.data.Dataset.from_tensor_slices((files_train, y_train))
            .shuffle(len(files_train), seed=42)
            .map(load_train, num_parallel_calls=AUTOTUNE)
            .batch(BATCH_SIZE).prefetch(AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((files_val, y_val))
          .map(load_eval, num_parallel_calls=AUTOTUNE)
          .batch(BATCH_SIZE).prefetch(AUTOTUNE))

test_ds = (tf.data.Dataset.from_tensor_slices((files_test, y_test))
           .map(load_eval, num_parallel_calls=AUTOTUNE)
           .batch(BATCH_SIZE).prefetch(AUTOTUNE))

print('Pipeline hazır')
# Out:
# Pipeline hazır

# %%
# ── 6. Model ──────────────────────────────────────────────────────
def build_model():
    backbone = MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        alpha=0.35,
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = layers.RandomFlip('horizontal')(inputs)
    x = layers.RandomRotation(0.08)(x)
    x = backbone(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    out_turb = layers.Dense(1, activation='sigmoid', name='turbidity')(x)
    out_part = layers.Dense(1, activation='sigmoid', name='particle')(x)
    out_col  = layers.Dense(1, activation='sigmoid', name='colour')(x)

    model = Model(inputs=inputs, outputs={
        'turbidity': out_turb,
        'particle':  out_part,
        'colour':    out_col,
    })
    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            'turbidity': 'binary_crossentropy',
            'particle':  'binary_crossentropy',
            'colour':    'binary_crossentropy',
        },
        loss_weights={
            'turbidity': 1.0,
            'particle':  1.0,
            'colour':    1.5,
        },
        metrics={
            'turbidity': ['accuracy'],
            'particle':  ['accuracy'],
            'colour':    ['accuracy'],
        }
    )
    return model

model = build_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_160_no_top.h5
# 2019640/2019640 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_flip_1       │ (None, 160, 160,  │          0 │ input_layer_1[0]… │
# │ (RandomFlip)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation_1   │ (None, 160, 160,  │          0 │ random_flip_1[0]… │
# │ (RandomRotation)    │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_0.35_1… │ (None, 5, 5,      │    410,208 │ random_rotation_… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_0.35… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ colour (Dense)      │ (None, 1)         │        129 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ particle (Dense)    │ (None, 1)         │        129 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ turbidity (Dense)   │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 574,563 (2.19 MB)
#  Trainable params: 164,355 (642.01 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %%
# ── 7. Eğitim ─────────────────────────────────────────────────────
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=7, restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        SAVE_PATH, monitor='val_loss', save_best_only=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6
    ),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

print(f'\nEn iyi model kaydedildi: {SAVE_PATH}')
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 699ms/step - colour_accuracy: 0.6570 - colour_loss: 0.6411 - loss: 2.0322 - particle_accuracy: 0.7874 - particle_loss: 0.4212 - turbidity_accuracy: 0.6908 - turbidity_loss: 0.6456 - val_colour_accuracy: 0.6591 - val_colour_loss: 0.6685 - val_loss: 1.5362 - val_particle_accuracy: 0.9773 - val_particle_loss: 0.1216 - val_turbidity_accuracy: 0.8864 - val_turbidity_loss: 0.4108 - learning_rate: 0.0010
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - colour_accuracy: 0.7633 - colour_loss: 0.4569 - loss: 1.2758 - particle_accuracy: 0.9807 - particle_loss: 0.1102 - turbidity_accuracy: 0.7874 - turbidity_loss: 0.4780 - val_colour_accuracy: 0.7500 - val_colour_loss: 0.3860 - val_loss: 1.1630 - val_particle_accuracy: 0.9545 - val_particle_loss: 0.0740 - val_turbidity_accuracy: 0.7500 - val_turbidity_loss: 0.5082 - learning_rate: 0.0010
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - colour_accuracy: 0.8841 - colour_loss: 0.2980 - loss: 0.9821 - particle_accuracy: 0.9855 - particle_loss: 0.0798 - turbidity_accuracy: 0.7778 - turbidity_loss: 0.4547 - val_colour_accuracy: 0.9545 - val_colour_loss: 0.2741 - val_loss: 1.0480 - val_particle_accuracy: 0.9773 - val_particle_loss: 0.0624 - val_turbidity_accuracy: 0.6818 - val_turbidity_loss: 0.5703 - learning_rate: 0.0010
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s
- val_colour_accuracy: 1.0000 - val_colour_loss: 0.0529 - val_loss: 0.2141 - val_particle_accuracy: 1.0000 - val_particle_loss: 0.0092 - val_turbidity_accuracy: 0.9773 - val_turbidity_loss: 0.1276 - learning_rate: 6.2500e-05
#
# En iyi model kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.keras

# %%
# ── 8. Training curve ─────────────────────────────────────────────
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 4, figsize=(22, 4))
metrics = [
    ('loss',                'Total loss'),
    ('turbidity_accuracy',  'Turbidity acc'),
    ('particle_accuracy',   'Particle acc'),
    ('colour_accuracy',     'Colour acc'),
]
for ax, (metric, title) in zip(axes, metrics):
    ax.plot(history.history[metric], label='train')
    ax.plot(history.history[f'val_{metric}'], label='val')
    ax.set_title(title)
    ax.legend()
plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=120)
plt.show()

# %%
# ── 9. Test seti değerlendirme ────────────────────────────────────
best_model = tf.keras.models.load_model(SAVE_PATH)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

y_true = {'turbidity': [], 'particle': [], 'colour': []}
y_pred = {'turbidity': [], 'particle': [], 'colour': []}
scores = {'turbidity': [], 'particle': [], 'colour': []}

for imgs, labels in test_ds:
    preds = best_model.predict(imgs, verbose=0)
    for key in ['turbidity', 'particle', 'colour']:
        y_true[key].extend(labels[key].numpy().flatten())
        scores[key].extend(preds[key].flatten())
        y_pred[key].extend((preds[key] > 0.5).flatten().astype(int))

for key in ['turbidity', 'particle', 'colour']:
    acc = accuracy_score(y_true[key], y_pred[key])
    f1  = f1_score(y_true[key], y_pred[key], zero_division=0)
    cm  = confusion_matrix(y_true[key], y_pred[key])
    sc  = scores[key]
    print(f'\n── {key} ──')
    print(f'  Accuracy : {acc:.4f}')
    print(f'  F1 Score : {f1:.4f}')
    print(f'  Score min/max/mean: {min(sc):.3f} / {max(sc):.3f} / {np.mean(sc):.3f}')
    print(f'  Confusion matrix:\n{cm}')
# Out:
# ── turbidity ──
#   Accuracy : 0.8889
#   F1 Score : 0.8718
#   Score min/max/mean: 0.001 / 0.998 / 0.437
#   Confusion matrix:
# [[23  1]
#  [ 4 17]]
#
# ── particle ──
#   Accuracy : 1.0000
#   F1 Score : 1.0000
#   Score min/max/mean: 0.001 / 1.000 / 0.473
#   Confusion matrix:
# [[24  0]
#  [ 0 21]]
#
# ── colour ──
#   Accuracy : 0.9556
#   F1 Score : 0.9524
#   Score min/max/mean: 0.000 / 1.000 / 0.461
#   Confusion matrix:
# [[23  0]
#  [ 2 20]]

# %%
# ── 10. Optimal threshold ─────────────────────────────────────────
for key in ['turbidity', 'particle', 'colour']:
    best_t, best_f1 = 0.5, 0
    for thresh in np.arange(0.05, 0.95, 0.05):
        yp = [1 if s > thresh else 0 for s in scores[key]]
        f1 = f1_score(y_true[key], yp, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_t  = thresh
    yp_best = [1 if s > best_t else 0 for s in scores[key]]
    acc = accuracy_score(y_true[key], yp_best)
    print(f'{key}: best_threshold={best_t:.2f}  acc={acc:.3f}  f1={best_f1:.3f}')
# Out:
# turbidity: best_threshold=0.55  acc=0.911  f1=0.895
# particle: best_threshold=0.15  acc=1.000  f1=1.000
# colour: best_threshold=0.35  acc=0.956  f1=0.952

# %%
# from PIL import Image
# import numpy as np
# import glob, os

# best_model = tf.keras.models.load_model(SAVE_PATH)

# images = sorted(glob.glob('/content/test_images/*.jpg') + glob.glob('/content/test_images/*.jpeg'))

# if not images:
#     print('Görüntü bulunamadı — /content/*.jpg formatında kaydet')
# else:
#     print(f"{'Dosya':<30} {'Contamination':>15} {'Colour':>10} {'Karar'}")
#     print('-' * 70)
#     for path in images:
#         img = Image.open(path).convert('RGB').resize((192, 192))
#         arr = np.expand_dims(np.array(img, dtype=np.float32) / 255.0, axis=0)
#         preds = best_model.predict(arr, verbose=0)
#         cont  = float(preds[0][0][0])
#         col   = float(preds[1][0][0])
#         karar = []
#         if cont > 0.25: karar.append('KİRLİ')
#         if col  > 0.05: karar.append('RENKLİ')
#         if not karar:   karar.append('TEMİZ')
#         fname = os.path.basename(path)
#         print(f'{fname:<30} {cont:>15.4f} {col:>10.4f}  {", ".join(karar)}')

# %%
# ── TFLite INT8 dönüşümü ──────────────────────────────────────────
import tensorflow as tf

# En iyi modeli Drive'dan yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

TFLITE_PATH = '/content/drive/MyDrive/models/MobileNetV2_a035.tflite'

def representative_dataset():
    for imgs, _ in train_ds:
        yield [imgs]

converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.float32  # çıkış float32 — hassasiyet kaybı önlenir

tflite_model = converter.convert()

with open(TFLITE_PATH, 'wb') as f:
    f.write(tflite_model)

print(f'Model boyutu: {len(tflite_model)/1024:.1f} KB')
print(f'Kaydedildi: {TFLITE_PATH}')

# Tensor sırasını kontrol et
interpreter = tf.lite.Interpreter(model_path=TFLITE_PATH)
interpreter.allocate_tensors()
output_details = interpreter.get_output_details()
for i, o in enumerate(output_details):
    print(f'[{i}] {o["name"]}  dtype={o["dtype"]}')
# Out:
# Saved artifact at '/tmp/tmp64mjrprz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   Dict[['turbidity', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)], ['particle', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)], ['colour', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]]
# Captures:
#   135950726591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726594384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726591696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726592656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726592848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726593616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726590736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726591504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726591120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726590928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725612752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726591888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950726593808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725611792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725612176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725612368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725612560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725613712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725613136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725613328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725613520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725611600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725614672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725614096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725614288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725614480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725611984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725615632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725615056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725615248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725615440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725612944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725613904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725617552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725617168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725617360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725614864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725618512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725617936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725618128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725618320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725615824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725619472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725618896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725619088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725619280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725616784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725620432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725619856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725620048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725620240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725617744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725620816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725618704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725622352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725622160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725619664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725623312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725622736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725622928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725623120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725620624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725624272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725623696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725623888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725624080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725621584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725625232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725624656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725624848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725625040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725622544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725625616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725625808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725623504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725627152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725627344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725627728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725625424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725626960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725627536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725624464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724301648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724301072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724300880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724301264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724301840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724303952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724303376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724303568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724303760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724301456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724304912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724304336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724304528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724304720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724302224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724305872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724305296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724305488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724305680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724303184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724306832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724306256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724306448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724306640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724304144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724305104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724308752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724308176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724308368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724308560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724306064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724309712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724309136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724309328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724309520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724310672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724310096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724310288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724310480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724307984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724311632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724311056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724311248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724311440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724308944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724309904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724313552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724313168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724313360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724310864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724314512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724313936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724314128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724314320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724311824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724315472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724314896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724315088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724315280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724312784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724316432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724315856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724316048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724316624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724317008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724315664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724314704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724316240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724316816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950724313744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725153040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725153424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725153808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725152848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725155344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725155536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725156880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725156688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725157840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725157264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725157456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725155152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725159760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725159184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725159376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725159568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725157072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725160720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725160144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725160336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725160528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725161680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725161104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725161296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725161488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725158992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725162640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725162448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725164560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725164176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725164368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725165520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725164944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725165136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725165328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725166480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725165904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725166096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725166288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725163792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725167440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725166864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725167056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725167248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725164752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725168400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725166672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725168976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725168208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725168592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725168784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725167824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725165712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135950725167632: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Model boyutu: 772.6 KB
# Kaydedildi: /content/drive/MyDrive/models/MobileNetV2_a035.tflite
# [0] StatefulPartitionedCall_1:1  dtype=<class 'numpy.float32'>
# [1] StatefulPartitionedCall_1:2  dtype=<class 'numpy.float32'>
# [2] StatefulPartitionedCall_1:0  dtype=<class 'numpy.float32'>
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# import numpy as np
# from PIL import Image
# import tensorflow as tf
# best_model = tf.keras.models.load_model(SAVE_PATH)
# # JPEG'i aç ama önce uint8 array'e çevir, sonra float yap
# img = Image.open("/content/con8633co1719.jpeg").convert("RGB")
# arr_uint8 = np.array(img, dtype=np.uint8)
# # uint8 direkt — ESP32'nin yaptığı gibi
# arr_float = np.expand_dims(arr_uint8.astype(np.float32) / 255.0, axis=0)
# preds = best_model.predict(arr_float, verbose=0)
# print(f"contamination: {preds[0][0][0]:.4f}")
# print(f"colour:        {preds[1][0][0]:.4f}")
# # Ayrıca TFLite ile de test et
# interpreter = tf.lite.Interpreter(model_path="/content/drive/MyDrive/wco_model_v7_int8.tflite")
# interpreter.allocate_tensors()
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()
# img_uint8 = np.expand_dims(arr_uint8, axis=0)
# interpreter.set_tensor(input_details[0]['index'], img_uint8)
# interpreter.invoke()
# raw0 = interpreter.get_tensor(output_details[0]['index'])[0][0]
# raw1 = interpreter.get_tensor(output_details[1]['index'])[0][0]
# scale = output_details[0]['quantization'][0]
# print(f"\nTFLite [0]: {int(raw0) * scale:.4f}")
# print(f"TFLite [1]: {int(raw1) * scale:.4f}")

# %%
# !xxd -i /content/drive/MyDrive/models/MobileNetV2_a035.tflite > /content/drive/MyDrive/models/MobileNetV2_a035.cpp

# %%
# with open('/content/drive/MyDrive/models/MobileNetV2_a035.cpp', 'r') as f:
#     content = f.read()

# content = (
#       '#include "MobileNetV1_a025.h"\n\n'
#       '#ifdef __has_attribute\n#define HAVE_ATTRIBUTE(x) __has_attribute(x)\n'
#       '#else\n#define HAVE_ATTRIBUTE(x) 0\n#endif\n'
#       '#if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))\n'
#       '#define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))\n'
#       '#else\n#define DATA_ALIGN_ATTRIBUTE\n#endif\n\n'
#       + content
#       .replace('unsigned char wco_model_v2_int8_tflite[]',
#                'const unsigned char g_wco_model_v2_data[] DATA_ALIGN_ATTRIBUTE')
#       .replace('unsigned int _content_drive_MyDrive_wco_model_v7_int8_tflite_len',
#                'const int g_wco_model_v2_data_len')
#   )

# with open('/content/wco_model_data.cpp', 'w') as f:
#       f.write(content)

# print('Hazır:', '/content/wco_model_data.cpp')
