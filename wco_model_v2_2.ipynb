# %% [markdown]
# # WCO Model v2
# **Output:** contamination + colour
# **Inference:** FastAPI server (Keras float32)
# **ESP32:** sadece görüntü toplar, inference yok

# %%
# ── 1. Drive mount ────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

DRIVE_DIR = '/content/drive/MyDrive/cropped192'
SAVE_PATH = '/content/drive/MyDrive/wco_model_v2.keras'
# Out:
# Mounted at /content/drive

# %%
# ── 2. Import ─────────────────────────────────────────────────────
import os, re
import numpy as np
import tensorflow as tf
import keras
from keras import layers, Model
from keras.applications import MobileNet
from sklearn.model_selection import train_test_split

IMG_SIZE   = 192
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE

print('TF version:', tf.__version__)
# Out:
# TF version: 2.19.0

# %%
# ── 3. Label parse ────────────────────────────────────────────────
# contamination = min(1, turbidity + particle)
# colour ayrı kalır
def parse_label(filename):
    m = re.match(r't(\d)_p(\d)_c(\d)_', filename)
    if not m:
        return None
    t, p, c = int(m.group(1)), int(m.group(2)), int(m.group(3))
    contamination = min(1, t + p)
    return np.array([contamination, c], dtype=np.float32)

all_files, all_labels = [], []

for fname in sorted(os.listdir(DRIVE_DIR)):
    if not fname.endswith('.jpg'):
        continue
    lbl = parse_label(fname)
    if lbl is None:
        print(f'SKIP: {fname}')
        continue
    all_files.append(os.path.join(DRIVE_DIR, fname))
    all_labels.append(lbl)

all_labels = np.array(all_labels, dtype=np.float32)
print(f'Toplam        : {len(all_files)} görüntü')
print(f'contamination : {all_labels[:,0].sum():.0f} pozitif')
print(f'colour        : {all_labels[:,1].sum():.0f} pozitif')
# Out:
# Toplam        : 148 görüntü
# contamination : 108 pozitif
# colour        : 73 pozitif

# %%
# ── 4. Train / val / test split ───────────────────────────────────
label_keys = [''.join(map(str, l.astype(int))) for l in all_labels]

files_train, files_temp, y_train, y_temp = train_test_split(
    all_files, all_labels,
    test_size=0.30, stratify=label_keys, random_state=42
)
label_keys_temp = [''.join(map(str, l.astype(int))) for l in y_temp]
files_val, files_test, y_val, y_test = train_test_split(
    files_temp, y_temp,
    test_size=0.50, stratify=label_keys_temp, random_state=42
)

print(f'Train : {len(files_train)}')
print(f'Val   : {len(files_val)}')
print(f'Test  : {len(files_test)}')
# Out:
# Train : 103
# Val   : 22
# Test  : 23

# %%
# ── 5. tf.data pipeline ───────────────────────────────────────────
augment = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.08),
], name='augmentation')

def load_train(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    img = augment(img, training=True)
    return img, {'contamination': label[0:1], 'colour': label[1:2]}

def load_eval(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img, {'contamination': label[0:1], 'colour': label[1:2]}

train_ds = (tf.data.Dataset.from_tensor_slices((files_train, y_train))
            .shuffle(len(files_train), seed=42)
            .map(load_train, num_parallel_calls=AUTOTUNE)
            .batch(BATCH_SIZE).prefetch(AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((files_val, y_val))
          .map(load_eval, num_parallel_calls=AUTOTUNE)
          .batch(BATCH_SIZE).prefetch(AUTOTUNE))

test_ds = (tf.data.Dataset.from_tensor_slices((files_test, y_test))
           .map(load_eval, num_parallel_calls=AUTOTUNE)
           .batch(BATCH_SIZE).prefetch(AUTOTUNE))

print('Pipeline hazır')
# Out:
# Pipeline hazır

# %%
# ── 6. Model ──────────────────────────────────────────────────────
def build_model():
    backbone = MobileNet(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        alpha=0.25,
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    out_cont = layers.Dense(1, activation='sigmoid', name='contamination')(x)
    out_c    = layers.Dense(1, activation='sigmoid', name='colour')(x)

    model = Model(inputs=inputs, outputs=[out_cont, out_c])
    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={'contamination': 'binary_crossentropy', 'colour': 'binary_crossentropy'},
        metrics={'contamination': ['accuracy'], 'colour': ['accuracy']}
    )
    return model

model = build_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_2_5_192_tf_no_top.h5
# 2108140/2108140 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 192, 192,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenet_0.25_192  │ (None, 6, 6, 256) │    218,544 │ input_layer_2[0]… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ mobilenet_0.25_1… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ contamination       │ (None, 1)         │        129 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ colour (Dense)      │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 251,698 (983.20 KB)
#  Trainable params: 33,154 (129.51 KB)
#  Non-trainable params: 218,544 (853.69 KB)

# %%
# ── 7. Eğitim ─────────────────────────────────────────────────────
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=7, restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        SAVE_PATH, monitor='val_loss', save_best_only=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6
    ),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

print(f'\nEn iyi model kaydedildi: {SAVE_PATH}')
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 658ms/step - colour_accuracy: 0.5146 - colour_loss: 0.8885 - contamination_accuracy: 0.6117 - contamination_loss: 1.0140 - loss: 1.8881 - val_colour_accuracy: 0.6364 - val_colour_loss: 0.6600 - val_contamination_accuracy: 0.7273 - val_contamination_loss: 0.7685 - val_loss: 1.4822 - learning_rate: 0.0010
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - colour_accuracy: 0.6311 - colour_loss: 0.7021 - contamination_accuracy: 0.7573 - contamination_loss: 0.5653 - loss: 1.3297 - val_colour_accuracy: 0.8182 - val_colour_loss: 0.4358 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.2872 - val_loss: 0.6807 - learning_rate: 0.0010
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - colour_accuracy: 0.6990 - colour_loss: 0.5680 - contamination_accuracy: 0.7767 - contamination_loss: 0.4535 - loss: 1.0469 - val_colour_accuracy: 0.8182 - val_colour_loss: 0.3346 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.1969 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - colour_accuracy: 0.7573 - colour_loss: 0.4190 - contamination_accuracy: 0.9029 - contamination_loss: 0.2207 - loss: 0.6532 - val_colour_accuracy: 0.9091 - val_colour_loss: 0.3586 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.1461 - val_loss: 0.4643 - learning_rate: 0.0010
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - colour_accuracy: 0.8350 - colour_loss: 0.4003 - contamination_accuracy: 0.8835 - contamination_loss: 0.3121 - loss: 0.7022 - val_colour_accuracy: 0.9091 - val_colour_loss: 0.2273 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.1341 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - colour_accuracy: 0.8350 - colour_loss: 0.4131 - contamination_accuracy: 0.9029 - contamination_loss: 0.1854 - loss: 0.5988 - val_colour_accuracy: 0.9545 - val_colour_loss: 0.1901 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.1211 - val_loss: 0.3058 - learning_rate: 0.0010
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 444ms/step - colour_accuracy: 0.9029 - colour_loss: 0.2911 - contamination_accuracy: 0.8544 - contamination_loss: 0.2520 - loss: 0.5223 - val_colour_accuracy: 0.9091 - val_colour_loss: 0.1994 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.1015 - val_loss: 0.2881 - learning_rate: 0.0010
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - colour_accuracy: 0.9515 - colour_loss: 0.2091 - contamination_accuracy: 0.9029 - contamination_loss: 0.2211 - loss: 0.4556 - val_colour_accuracy: 0.9545 - val_colour_loss: 0.1487 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.1160 - val_loss: 0.3019 - learning_rate: 0.0010
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - colour_accuracy: 0.9223 - colour_loss: 0.2240 - contamination_accuracy: 0.9223 - contamination_loss: 0.2100 - loss: 0.4394 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.1352 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0921 - val_loss: 0.2277 - learning_rate: 0.0010
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - colour_accuracy: 0.9417 - colour_loss: 0.1836 - contamination_accuracy: 0.9126 - contamination_loss: 0.2329 - loss: 0.4167 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.1214 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0882 - val_loss: 0.2149 - learning_rate: 0.0010
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - colour_accuracy: 0.9806 - colour_loss: 0.1297 - contamination_accuracy: 0.9029 - contamination_loss: 0.2078 - loss: 0.3294 - val_colour_accuracy: 0.9545 - val_colour_loss: 0.1056 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0911 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - colour_accuracy: 0.9417 - colour_loss: 0.1615 - contamination_accuracy: 0.9223 - contamination_loss: 0.1668 - loss: 0.3338 - val_colour_accuracy: 0.9545 - val_colour_loss: 0.1033 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0977 - val_loss: 0.1902 - learning_rate: 0.0010
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - colour_accuracy: 0.9612 - colour_loss: 0.1259 - contamination_accuracy: 0.9417 - contamination_loss: 0.1511 - loss: 0.2846 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.1024 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0864 - val_loss: 0.1909 - learning_rate: 0.0010
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - colour_accuracy: 0.9709 - colour_loss: 0.1150 - contamination_accuracy: 0.9126 - contamination_loss: 0.2049 - loss: 0.3215 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.1077 - val_contamination_accuracy: 0.9091 - val_contamination_loss: 0.1001 - val_loss: 0.2188 - learning_rate: 0.0010
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - colour_accuracy: 0.9515 - colour_loss: 0.1445 - contamination_accuracy: 0.9126 - contamination_loss: 0.1837 - loss: 0.3513 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0811 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0885 - val_loss: 0.1772 - learning_rate: 0.0010
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - colour_accuracy: 0.9709 - colour_loss: 0.1029 - contamination_accuracy: 0.9029 - contamination_loss: 0.1863 - loss: 0.3030 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0705 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0908 - val_loss: 0.1589 - learning_rate: 0.0010
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0759 - contamination_accuracy: 0.9029 - contamination_loss: 0.1598 - loss: 0.2453 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0792 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0882 - val_loss: 0.1734 - learning_rate: 0.0010
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0788 - contamination_accuracy: 0.9029 - contamination_loss: 0.1538 - loss: 0.2312 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0679 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0942 - val_loss: 0.1763 - learning_rate: 0.0010
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 907ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0852 - contamination_accuracy: 0.9417 - contamination_loss: 0.1405 - loss: 0.2356 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0610 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0846 - val_loss: 0.1461 - learning_rate: 0.0010
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0627 - contamination_accuracy: 0.9417 - contamination_loss: 0.1323 - loss: 0.2061 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0527 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0851 - val_loss: 0.1387 - learning_rate: 0.0010
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0694 - contamination_accuracy: 0.9320 - contamination_loss: 0.1593 - loss: 0.2321 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0826 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0828 - val_loss: 0.1638 - learning_rate: 0.0010
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - colour_accuracy: 0.9612 - colour_loss: 0.0816 - contamination_accuracy: 0.9126 - contamination_loss: 0.1714 - loss: 0.2629 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0456 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0813 - val_loss: 0.1285 - learning_rate: 0.0010
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0356 - contamination_accuracy: 0.8932 - contamination_loss: 0.1709 - loss: 0.2043 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0443 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0804 - val_loss: 0.1278 - learning_rate: 0.0010
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - colour_accuracy: 0.9709 - colour_loss: 0.0655 - contamination_accuracy: 0.9515 - contamination_loss: 0.1565 - loss: 0.2128 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0475 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0780 - val_loss: 0.1205 - learning_rate: 0.0010
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0412 - contamination_accuracy: 0.9320 - contamination_loss: 0.1558 - loss: 0.1972 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0422 - val_contamination_accuracy: 0.9545 - val_contamination_loss: 0.0847 - val_loss: 0.1353 - learning_rate: 0.0010
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 442ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0503 - contamination_accuracy: 0.9029 - contamination_loss: 0.1701 - loss: 0.2118 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0422 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0812 - val_loss: 0.1158 - learning_rate: 0.0010
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0456 - contamination_accuracy: 0.9320 - contamination_loss: 0.1327 - loss: 0.1892 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0414 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0789 - val_loss: 0.1219 - learning_rate: 0.0010
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0506 - contamination_accuracy: 0.9417 - contamination_loss: 0.1296 - loss: 0.1829 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0383 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0760 - val_loss: 0.1114 - learning_rate: 0.0010
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0432 - contamination_accuracy: 0.9320 - contamination_loss: 0.1275 - loss: 0.1696 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0460 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0709 - val_loss: 0.1126 - learning_rate: 0.0010
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0328 - contamination_accuracy: 0.9417 - contamination_loss: 0.1218 - loss: 0.1492 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0314 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0730 - val_loss: 0.0983 - learning_rate: 0.0010
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0324 - contamination_accuracy: 0.9126 - contamination_loss: 0.1531 - loss: 0.1874 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0317 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0748 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0331 - contamination_accuracy: 0.9223 - contamination_loss: 0.1176 - loss: 0.1586 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0317 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0923 - val_loss: 0.1015 - learning_rate: 0.0010
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0320 - contamination_accuracy: 0.9515 - contamination_loss: 0.1331 - loss: 0.1569 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0278 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0806 - val_loss: 0.1110 - learning_rate: 0.0010
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0305 - contamination_accuracy: 0.9126 - contamination_loss: 0.1703 - loss: 0.2003 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0282 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0747 - val_loss: 0.1009 - learning_rate: 5.0000e-04
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0285 - contamination_accuracy: 0.9029 - contamination_loss: 0.1643 - loss: 0.1870 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0290 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0748 - val_loss: 0.0958 - learning_rate: 5.0000e-04
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0401 - contamination_accuracy: 0.9612 - contamination_loss: 0.1207 - loss: 0.1649 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0261 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0770 - val_loss: 0.1041 - learning_rate: 5.0000e-04
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0223 - contamination_accuracy: 0.9320 - contamination_loss: 0.1442 - loss: 0.1575 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0288 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0750 - val_loss: 0.1022 - learning_rate: 5.0000e-04
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0169 - contamination_accuracy: 0.9417 - contamination_loss: 0.1144 - loss: 0.1366 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0269 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0796 - val_loss: 0.0915 - learning_rate: 5.0000e-04
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0395 - contamination_accuracy: 0.9320 - contamination_loss: 0.1788 - loss: 0.1940 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0213 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0781 - val_loss: 0.0916 - learning_rate: 5.0000e-04
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0313 - contamination_accuracy: 0.9223 - contamination_loss: 0.1345 - loss: 0.1751 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0226 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0810 - val_loss: 0.0982 - learning_rate: 5.0000e-04
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0373 - contamination_accuracy: 0.9320 - contamination_loss: 0.1403 - loss: 0.1742 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0305 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0829 - val_loss: 0.1016 - learning_rate: 5.0000e-04
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0263 - contamination_accuracy: 0.9612 - contamination_loss: 0.1048 - loss: 0.1345 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0271 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0850 - val_loss: 0.0971 - learning_rate: 2.5000e-04
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0330 - contamination_accuracy: 0.9320 - contamination_loss: 0.1318 - loss: 0.1774 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0256 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0831 - val_loss: 0.0967 - learning_rate: 2.5000e-04
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - colour_accuracy: 0.9903 - colour_loss: 0.0331 - contamination_accuracy: 0.9417 - contamination_loss: 0.1313 - loss: 0.1548 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0270 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0819 - val_loss: 0.1007 - learning_rate: 2.5000e-04
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - colour_accuracy: 1.0000 - colour_loss: 0.0331 - contamination_accuracy: 0.9612 - contamination_loss: 0.1104 - loss: 0.1373 - val_colour_accuracy: 1.0000 - val_colour_loss: 0.0265 - val_contamination_accuracy: 1.0000 - val_contamination_loss: 0.0814 - val_loss: 0.1019 - learning_rate: 1.2500e-04
#
# En iyi model kaydedildi: /content/drive/MyDrive/wco_model_v2.keras

# %%
# ── 8. Training curve ─────────────────────────────────────────────
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 4))
for ax, metric in zip(axes, ['loss', 'contamination_accuracy', 'colour_accuracy']):
    ax.plot(history.history[metric], label='train')
    ax.plot(history.history[f'val_{metric}'], label='val')
    ax.set_title(metric)
    ax.legend()
plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=120)
plt.show()

# %%
# ── 9. Test seti değerlendirme ────────────────────────────────────
# Drive'daki kaydedilen en iyi modeli yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

y_true_cont, y_true_c = [], []
y_pred_cont, y_pred_c = [], []
scores_cont, scores_c = [], []

for imgs, labels in test_ds:
    preds = best_model.predict(imgs, verbose=0)
    y_true_cont.extend(labels['contamination'].numpy().flatten())
    y_true_c.extend(labels['colour'].numpy().flatten())
    scores_cont.extend(preds[0].flatten())
    scores_c.extend(preds[1].flatten())
    y_pred_cont.extend((preds[0] > 0.5).flatten())
    y_pred_c.extend((preds[1] > 0.5).flatten())

for name, yt, yp, sc in [
    ('contamination', y_true_cont, y_pred_cont, scores_cont),
    ('colour',        y_true_c,    y_pred_c,    scores_c)
]:
    acc = accuracy_score(yt, yp)
    f1  = f1_score(yt, yp, zero_division=0)
    cm  = confusion_matrix(yt, yp)
    print(f'\n── {name} ──')
    print(f'  Accuracy : {acc:.4f}')
    print(f'  F1 Score : {f1:.4f}')
    print(f'  Score min/max/mean: {min(sc):.3f} / {max(sc):.3f} / {np.mean(sc):.3f}')
    print(f'  Confusion matrix:\n{cm}')
# Out:
# ── contamination ──
#   Accuracy : 1.0000
#   F1 Score : 1.0000
#   Score min/max/mean: 0.031 / 1.000 / 0.748
#   Confusion matrix:
# [[ 6  0]
#  [ 0 17]]
#
# ── colour ──
#   Accuracy : 1.0000
#   F1 Score : 1.0000
#   Score min/max/mean: 0.003 / 0.999 / 0.454
#   Confusion matrix:
# [[12  0]
#  [ 0 11]]

# %%
# ── 10. Optimal threshold ─────────────────────────────────────────
for name, yt, sc in [
    ('contamination', y_true_cont, scores_cont),
    ('colour',        y_true_c,    scores_c)
]:
    best_t, best_f1 = 0.5, 0
    for thresh in np.arange(0.05, 0.95, 0.05):
        yp = [1 if s > thresh else 0 for s in sc]
        f1 = f1_score(yt, yp, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_t  = thresh
    yp_best = [1 if s > best_t else 0 for s in sc]
    acc = accuracy_score(yt, yp_best)
    print(f'{name}: best_threshold={best_t:.2f}  acc={acc:.3f}  f1={best_f1:.3f}')
# Out:
# contamination: best_threshold=0.25  acc=1.000  f1=1.000
# colour: best_threshold=0.05  acc=1.000  f1=1.000

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 4))
for ax, metric in zip(axes, ['loss', 'contamination_accuracy', 'colour_accuracy']):
    ax.plot(history.history[metric], label='train')
    ax.plot(history.history[f'val_{metric}'], label='val')
    ax.set_title(metric)
    ax.legend()
plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=120)
plt.show()

# %%
from PIL import Image
import numpy as np
import glob, os

best_model = tf.keras.models.load_model(SAVE_PATH)

images = sorted(glob.glob('/content/*.jpg') + glob.glob('/content/*.jpeg'))

if not images:
    print('Görüntü bulunamadı — /content/*.jpg formatında kaydet')
else:
    print(f"{'Dosya':<30} {'Contamination':>15} {'Colour':>10} {'Karar'}")
    print('-' * 70)
    for path in images:
        img = Image.open(path).convert('RGB').resize((192, 192))
        arr = np.expand_dims(np.array(img, dtype=np.float32) / 255.0, axis=0)
        preds = best_model.predict(arr, verbose=0)
        cont  = float(preds[0][0][0])
        col   = float(preds[1][0][0])
        karar = []
        if cont > 0.25: karar.append('KİRLİ')
        if col  > 0.05: karar.append('RENKLİ')
        if not karar:   karar.append('TEMİZ')
        fname = os.path.basename(path)
        print(f'{fname:<30} {cont:>15.4f} {col:>10.4f}  {", ".join(karar)}')
# Out:
# Dosya                            Contamination     Colour Karar
# ----------------------------------------------------------------------
# t0-p0-c0.jpeg                           0.0317     0.0106  TEMİZ
# t0-p0-c0_2.jpeg                         0.0359     0.0081  TEMİZ
# t0-p0-c1.jpeg                           0.0650     0.7947  RENKLİ
# t0-p0-c1_2.jpeg                         0.1218     0.9869  RENKLİ
# t0-p1-c0.jpeg                           0.9986     0.0006  KİRLİ
# t0-p1-c0_2.jpeg                         0.9996     0.0014  KİRLİ
# t0-p1-c1.jpeg                           0.9848     0.4647  KİRLİ, RENKLİ
# t0-p1-c1_2.jpeg                         0.9985     0.3333  KİRLİ, RENKLİ
# t1-p1-c0.jpeg                           0.9986     0.0001  KİRLİ
# t1-p1-c0_2.jpeg                         0.9999     0.0003  KİRLİ
# t1-p1-c1.jpeg                           0.9991     0.9521  KİRLİ, RENKLİ

# %%
# ── TFLite INT8 dönüşümü ──────────────────────────────────────────
import tensorflow as tf

# En iyi modeli Drive'dan yükle
best_model = tf.keras.models.load_model(SAVE_PATH)

TFLITE_PATH = '/content/drive/MyDrive/wco_model_v2_int8.tflite'

def representative_dataset():
    for imgs, _ in train_ds:
        yield [imgs]

converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

tflite_model = converter.convert()

with open(TFLITE_PATH, 'wb') as f:
    f.write(tflite_model)

print(f'Model boyutu: {len(tflite_model)/1024:.1f} KB')
print(f'Kaydedildi: {TFLITE_PATH}')

# Tensor sırasını kontrol et
interpreter = tf.lite.Interpreter(model_path=TFLITE_PATH)
interpreter.allocate_tensors()
output_details = interpreter.get_output_details()
for i, o in enumerate(output_details):
    print(f'[{i}] {o["name"]}  dtype={o["dtype"]}')
# Out:
# Saved artifact at '/tmp/tmpezxvrxq3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 192, 192, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]
# Captures:
#   133992813001040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813002192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812997968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812999120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812992976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812992592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813001616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812999888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812993360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813000464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813000848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812998160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812993744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813000656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812997584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812998928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812998736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813001424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813000272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812992208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812995088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813002000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812999312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812998352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813002576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812998544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813000080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813001232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812999504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813001808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812999696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992813002384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992812994896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811364624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811366160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811367120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811367504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811364816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811368656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811368080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811368464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811365968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811369040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811369424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811366928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811367888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811371344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811368848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811372496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811372304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811372880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811373264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811371728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811375376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811375184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811372688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811376336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811377296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811376720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811374608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811378256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811378064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811375568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811378640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811380176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811377488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811380368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809972176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992811379408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809972944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809971984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809971792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809972368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809973712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809972752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809974480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809974672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809974864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809972560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809973328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809976400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133992809975248: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Model boyutu: 336.3 KB
# Kaydedildi: /content/drive/MyDrive/wco_model_v2_int8.tflite
# [0] StatefulPartitionedCall_1:1  dtype=<class 'numpy.uint8'>
# [1] StatefulPartitionedCall_1:0  dtype=<class 'numpy.uint8'>
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# Threshold güncelle
cont_idx   = 1
colour_idx = 0

CONT_THRESHOLD   = 0.25
COLOUR_THRESHOLD = 0.10  # 0.05 → 0.10

print(f"{'Dosya':<25} {'Contamination':>15} {'Colour':>8} {'Karar'}")
print('-' * 65)

for path in images:
    img = Image.open(path).convert('RGB').resize((192, 192))
    arr_uint8 = np.expand_dims(np.array(img, dtype=np.uint8), axis=0)

    interpreter.set_tensor(input_details[0]['index'], arr_uint8)
    interpreter.invoke()

    raw_cont = interpreter.get_tensor(output_details[cont_idx]['index'])[0][0]
    raw_col  = interpreter.get_tensor(output_details[colour_idx]['index'])[0][0]
    t_cont = int(raw_cont) * out_scale
    t_col  = int(raw_col)  * out_scale

    karar = []
    if t_cont > CONT_THRESHOLD:   karar.append('KİRLİ')
    if t_col  > COLOUR_THRESHOLD: karar.append('RENKLİ')
    if not karar: karar.append('TEMİZ')

    fname = os.path.basename(path)
    print(f'{fname:<25} {t_cont:>15.4f} {t_col:>8.4f}  {", ".join(karar)}')
# Out:
# Dosya                       Contamination   Colour Karar
# -----------------------------------------------------------------
# t0-p0-c0.jpeg                      0.0430   0.0898  TEMİZ
# t0-p0-c0_2.jpeg                    0.0430   0.0781  TEMİZ
# t0-p0-c1.jpeg                      0.0781   0.8984  RENKLİ
# t0-p0-c1_2.jpeg                    0.1680   0.8789  RENKLİ
# t0-p1-c0.jpeg                      0.9961   0.0117  KİRLİ
# t0-p1-c0_2.jpeg                    0.9961   0.0547  KİRLİ
# t0-p1-c1.jpeg                      0.9844   0.5000  KİRLİ, RENKLİ
# t0-p1-c1_2.jpeg                    0.9961   0.5664  KİRLİ, RENKLİ
# t1-p1-c0.jpeg                      0.9961   0.0000  KİRLİ
# t1-p1-c0_2.jpeg                    0.9961   0.0039  KİRLİ
# t1-p1-c1.jpeg                      0.9961   0.9648  KİRLİ, RENKLİ

# %%
# .tflite → C header
HEADER_PATH = '/content/drive/MyDrive/wco_model_v2_data.h'

with open(TFLITE_PATH, 'rb') as f:
    tflite_bytes = f.read()

hex_array = ', '.join([f'0x{b:02x}' for b in tflite_bytes])
array_len = len(tflite_bytes)

c_header = f"""#ifndef WCO_MODEL_H
#define WCO_MODEL_H

// Output tensor mapping (TFLite sırası Keras'tan farklı):
//   output_details[0] -> :1 -> COLOUR
//   output_details[1] -> :0 -> CONTAMINATION
// Threshold: contamination > 0.25, colour > 0.10

const unsigned int wco_model_len = {array_len};
const unsigned char wco_model_data[] = {{
  {hex_array}
}};

#endif // WCO_MODEL_H
"""

with open(HEADER_PATH, 'w') as f:
    f.write(c_header)

print(f'Kaydedildi: {HEADER_PATH}')
print(f'Boyut: {array_len} byte ({array_len/1024:.1f} KB)')
# Out:
# Kaydedildi: /content/drive/MyDrive/wco_model_v2_data.h
# Boyut: 344344 byte (336.3 KB)
